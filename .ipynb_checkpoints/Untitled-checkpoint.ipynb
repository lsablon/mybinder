# %%
using Pkg
pkg"activate ."
pkg"instantiate"
using HDF5, Plots, Plots.Measures
plotlyjs()
# Out:
#   Activating new environment at `~/mybinder/Project.toml`
#   No Changes to `~/mybinder/Project.toml`
#   No Changes to `~/mybinder/Manifest.toml`
# Plots.PlotlyJSBackend()

# %%
pread = Plots.hdf5plot_read("o2_box_plot.hdf5")
display(pread)
